# %% [markdown]
# ## TYPE CASTING

# %% [markdown]
# ## ## IMPLICIT

# %%
a = 10
b = 2.3
c = a + b 
print(c)
# Out:
# 12.3

# %% [markdown]
# ## EXPLICIT

# %%
a = "10"
b = "20"

result = int(a) + int(b)

# %% [markdown]
# ## question

# %% [markdown]
# 1. convert "25" in to integer

# %%
a = "25"
num = int(a)
print(num)
# Out:
# 25

# %% [markdown]
# 2.  convert 10 in to float

# %%
a = 10 
b = float(a)
print(b)
# Out:
# 10.0

# %% [markdown]
# 3. convert 5.7 into integer

# %%
a = 5.7
b = int(a)
print(b)
# Out:
# 5

# %% [markdown]
# 4. convert 100 in to string

# %%
a = 100
b = str(a)
print(b)
# Out:
# 100

# %% [markdown]
# 5. convert (10, 20, 30) in to list

# %%
a = (10,20,30,40)
l = list(a)
print(l)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# 6. convert [1,2,2,3,3] in to set

# %%
a = [1,2,2,3,3,]
s = set(a)
print(s)
# Out:
# {1, 2, 3}
