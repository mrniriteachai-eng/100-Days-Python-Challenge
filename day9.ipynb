# %% [markdown]
# ## STRINGS

# %%
name = "Mrniriteach"
print(name)
# Out:
# Mrniriteach

# %% [markdown]
# ## ACCSESS CHARACTERS

# %%
print(name[0])
print(name[1])
# Out:
# M
# r

# %% [markdown]
# ## STRING SLICING

# %%
print(name[0:3])
# Out:
# Mrn

# %% [markdown]
# ## STRING METHOD

# %%
text = "python"

print(text.upper())
print(text.lower())
# Out:
# PYTHON
# python

# %% [markdown]
# ## CONCATENATION

# %%
first="hello"
second="word"

print(first + " " + second)
# Out:
# hello word

# %% [markdown]
# ## LENGTH OF STRING

# %%
print(len(name))
# Out:
# 11
