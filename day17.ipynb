# %% [markdown]
# ## PROJECT 5

# %%
expenses = {}

def add_expenses():
    item = input("enter item: ")
    amount = int(input("enter a amount: "))

    expenses[item] = amount
    print("expense added")

    def show_expenses():
        if not expenses:
             print("no expenses")

             for item, amount in expenses. items():
                 
                 print(item, ":", amount)

                 def total_expense():
                      total = sum(expenses. values)

                      print(" total kharcha:", total)



def highest_expense():
     if expenses:
           item = max(expenses, key=expenses. get)
           print("highest kharcha:", item, "-", expenses[item])


           while True:
                 print("\n1.add 2. show 3. total 4. highest 5. exit")
                 choice = input ("enter choice")
                 if choice == "1":
                           add_expenses()


                 elif choice == "5":
                       print("goodby")
                       break
                 else:
                        
                     print("invalid")
