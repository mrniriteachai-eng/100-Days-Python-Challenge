# %% [markdown]
# ## PROJECT 6

# %% [markdown]
# ## SMART RESULT DECISION SYSTEM

# %%
marks = int(input("enter marks: "))

if marks >= 80:
    print("A+")
    
elif marks >= 60:
    print("B")

elif marks >=40:
    print("C")
else:
    print("fail")
# Out:
# fail
