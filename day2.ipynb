# %% [markdown]
# ## variable
# varible is a like a container
# eg
# bottle = varible
# water = data

# %%
name = "nirmal"
age = "18"
print(name)
print(age)
# Out:
# nirmal
# 18

# %% [markdown]
# name = "nirmal"
#
# name = variable name
# =  operator assign garne
# "nirmal" = value

# %% [markdown]
# print("name)

# %%
name = "ram"
name = "shyam"
print(name)
# Out:
# shyam

# %% [markdown]
# ## RULE OF VARIABLE

# %% [markdown]
# - space use nagarne
# - number bata start nagarne
# - simple name use nagarne
#
#
# example : name
# my_name = true
# 1name = false
