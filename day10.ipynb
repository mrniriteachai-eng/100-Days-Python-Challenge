# %% [markdown]
# ## LIST

# %%
numbers = [1, 2, 3, 4, 5]
name = ["ram","shyam","hari"]

# %%
mix = [1, "ram", 3.5]

# %% [markdown]
# ## ACCESSING ELEMENTS

# %%
names = ["ram", "shyam", "hari"]
print(names[0])
print(names[1])
# Out:
# ram
# shyam

# %% [markdown]
# ## CHANGING VAUES

# %%
names[1] ="sita"
print(names)
# Out:
# ['ram', 'sita', 'hari']

# %% [markdown]
# ## ADDING ITEMS

# %%
names.append("gita")

# %% [markdown]
# ## REMOVING ITENS

# %%
names.remove("ram")

# %% [markdown]
# ## LOOPS WITH LIST

# %%
for name in names:
    print(name)

# %% [markdown]
# ## PROJECT

# %%
marks = [80, 75, 90, 95]

total = sum(marks)
average = total / len(marks)

print("total:",total)
print("average:",average)
# Out:
# total: 340
# average: 85.0
