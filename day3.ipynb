# %% [markdown]
# ## DATA TYPES
#    - string
#    - integer
#    - float
#    - boolean

# %% [markdown]
# ## STRING
#
#  - rule : " nirmal "

# %%
name = "nirrmal"

# %% [markdown]
# INTEGER
# - integer vaneko whole number hunxa
# - 18,29,30
# - age,marks,counts

# %%
age = 18

# %% [markdown]
# FLOAT
#
# - decimal number
# - 99.7,3.14
# - money, weight,height

# %%
price = 99.5

# %% [markdown]
# BOOLEAN
#
# - true/false

# %%
is_students = True

# %%
name = "nirmal"
age = 18
price = 99.5
is_student = True

print(name)
print(age)
print(price)
print(is_student)
# Out:
# nirmal
# 18
# 99.5
# True

# %%
print(type(name))
print(type(age))
print(type(price))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
